# %%
import matplotlib.pyplot as plt
#plt.style.use('classic')
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv("LOG - Sheet2.csv")

# %%
df.columns
# Out:
# Index(['intExpID', 'Column', 'total_users', 'intSeg', 'intArr', 'intDel',
#        'intSta', 'intRep', 'intDelRate', 'intActRate', 'intByteSize',
#        'floatBuf', 'algorithm_used', 'Seg_Dur', 'Codec', 'Width', 'Height',
#        'Resolutions', 'FPS', 'Play_Pos', 'RTT', 'Protocol', 'Clae', 'Duanmu',
#        'Yin', 'Yu', 'P1203', 'log_Clae', 'log_Duanmu', 'log_Yin', 'log_Yu',
#        'log_P1203', 'intUser', 'port', 'rtt_qos', 'tp_qos', 'p_qos'],
#       dtype='object')

# %%
df['Column'].unique()
# Out:
# array([ 2,  1,  4,  5,  9,  8,  7, 10, 11])

# %%
bba =df[(df['algorithm_used']=='bba')]

# %%
logistic =df[(df['algorithm_used']=='logistic')]

# %%
elastic = df[(df['algorithm_used']=='elastic')]

# %%
arbiter = df[(df['algorithm_used']=='arbiter')]

# %%
conventional = df[(df['algorithm_used']=='conventional')]

# %%
exponential = df[(df['algorithm_used']=='exponential')]

# %%
bba.shape[0]
# Out:
# 1560

# %%
logistic.shape[0]
# Out:
# 1680

# %%
bba_df_8 =bba[(bba['Column']==8) & (bba['total_users']==2) & (bba['intUser']==1) ]

# %%
elastic_df_8 =elastic[(elastic['Column']==8) & (elastic['total_users']==2) & (elastic['intUser']==1) ]

# %%
arbiter_df_8 = arbiter[(arbiter['Column']==8) & (arbiter['total_users']==2) & (arbiter['intUser']==1) ]

# %%
elastic_df_10 =elastic[(elastic['Column']==10) & (elastic['total_users']==2) & (elastic['intUser']==1) ]

# %%
arbiter_df_10 = arbiter[(arbiter['Column']==10) & (arbiter['total_users']==2) & (arbiter['intUser']==1) ]

# %%
conv_df_10 =conventional[(conventional['Column']==10) & (conventional['total_users']==2) & (conventional['intUser']==1) ]

# %%
conv_df_8 =conventional[(conventional['Column']==8) & (conventional['total_users']==2) & (conventional['intUser']==2) ]

# %%
exp_df_10 =exponential[(exponential['Column']==10) & (exponential['total_users']==2) & (exponential['intUser']==1) ]

# %%
exp_df_8 =exponential[(exponential['Column']==8) & (exponential['total_users']==2) & (exponential['intUser']==2) ]

# %%
logistic_df_8 =logistic[(logistic['Column']==8) & (logistic['total_users']==2) & (logistic['intUser']==1) ]

# %%
bba_df_10 =bba[(bba['Column']==10) & (bba['total_users']==2) & (bba['intUser']==2) ]

# %%
logistic_df_10 =logistic[(logistic['Column']==10) & (logistic['total_users']==2) & (logistic['intUser']==2) ]

# %%
bba_df_8.shape[0]
# Out:
# 60

# %%
bba_df_8['algorithm_used'].unique()
# Out:
# array(['bba'], dtype=object)

# %%
import matplotlib.patheffects as mpe
import matplotlib

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(6,3.5)) 
plt.step(bba_df_10['intSeg'], bba_df_10['P1203'], label='BBA-2 +' )
plt.step(logistic_df_10['intSeg'], logistic_df_10['P1203'], label='Logistic',linestyle='--', color='orange')
#lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 6 - 14 Mbps')
plt.grid(True)
plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('P.1203', fontsize=12, color='black')
plt.yticks([2,2.5,3,3.5,4])  
plt.savefig('SIMONI/bba_logistic_14MBPS_P1203.png', format='png')

# %%
fig = plt.figure()


with plt.style.context('Solarize_Light2'):
    fig.set_facecolor('white')
    plt.rcParams['axes.facecolor'] = 'white'
    plt.plot(bba_df_10['intSeg'], bba_df_10['intSta'], label='BBA-2 +')
    plt.plot(logistic_df_10['intSeg'], logistic_df_10['intSta'], label='Logistic',linestyle='--',color='orange')
    plt.title('Bandwidth: 6 - 14 Mbps', fontsize=12)
    plt.xlabel('Segments (2 sec)', fontsize=12, color='black')
    plt.ylabel('Stall (ms)', fontsize=12, color='black')
    plt.legend(frameon=False)
    plt.grid(axis='y', c='grey',alpha=0.2)
    plt.grid(axis='x', c='grey',alpha=0.2)
    plt.tick_params(axis='x', colors='black')
    plt.tick_params(axis='y', colors='black')
    plt.savefig('SIMONI/bba_logistic_14MBPS_stall.png', format='png')

# %%
fig = plt.figure()


with plt.style.context('Solarize_Light2'):
    fig.set_facecolor('white')
    plt.rcParams['axes.facecolor'] = 'white'
    plt.plot(bba_df_8['intSeg'], bba_df_8['intSta'], label='BBA-2 +')
    plt.plot(logistic_df_8['intSeg'], logistic_df_8['intSta'], label='Logistic',linestyle='--',color='orange')
    plt.title('Bandwidth: 0.5 - 4 Mbps', fontsize=12)
    plt.xlabel('Segments (2 sec)', fontsize=12, color='black')
    plt.ylabel('Stall (ms)', fontsize=12, color='black')
    plt.legend(frameon=False)
    plt.grid(axis='y', c='grey',alpha=0.2)
    plt.grid(axis='x', c='grey',alpha=0.2)
    plt.tick_params(axis='x', colors='black')
    plt.tick_params(axis='y', colors='black')
    plt.savefig('SIMONI/bba_logistic_4MBPS_stall.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(6,3.5)) 
plt.step(bba_df_8['intSeg'], bba_df_8['P1203'], label='BBA-2 +' )
plt.step(logistic_df_8['intSeg'], logistic_df_8['P1203'], label='Logistic',linestyle='--', color='orange')
#lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 0.5 - 4 Mbps')
plt.grid(True)
#plt.subplots_adjust(right=0.78)
plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('P.1203', fontsize=12, color='black')
plt.yticks([0.5,1,1.5,2,2.5]) 
plt.savefig('SIMONI/bba_logistic_4MBPS_P1203.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(6,3.5)) 
plt.step(elastic_df_10['intSeg'], bba_df_10['P1203'], label='Elastic' )
plt.step(arbiter_df_10['intSeg'], arbiter_df_10['P1203'], label='Arbiter +',linestyle='--', color='orange')
#lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 6 - 14 Mbps')
plt.grid(True)
plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('P.1203', fontsize=12, color='black')
plt.yticks([2,2.5,3,3.5,4]) 
plt.savefig('SIMONI/elastic_arbiter_14MBPS_P1203.png', format='png')

# %%
fig = plt.figure()


with plt.style.context('Solarize_Light2'):
    fig.set_facecolor('white')
    plt.rcParams['axes.facecolor'] = 'white'
    plt.plot(elastic_df_10['intSeg'], elastic_df_10['intSta'], label='Elastic')
    plt.plot(arbiter_df_10['intSeg'], arbiter_df_10['intSta'], label='Arbiter +',linestyle='--',color='orange')
    plt.title('Bandwidth: 6 - 14 Mbps', fontsize=12)
    plt.xlabel('Segments (2 sec)', fontsize=12, color='black')
    plt.ylabel('Stall (ms)', fontsize=12, color='black')
    plt.legend(frameon=False)
    plt.grid(axis='y', c='grey',alpha=0.2)
    plt.grid(axis='x', c='grey',alpha=0.2)
    plt.tick_params(axis='x', colors='black')
    plt.tick_params(axis='y', colors='black')
    plt.savefig('SIMONI/elastic_arbiter_14MBPS_stall.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(6,3.5)) 
plt.step(elastic_df_8['intSeg'], bba_df_8['P1203'], label='Elastic' )
plt.step(arbiter_df_8['intSeg'], arbiter_df_8['P1203'], label='Arbiter +',linestyle='--', color='orange')
#lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 0.5 - 4 Mbps')
plt.grid(True)
plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('P.1203', fontsize=12, color='black')
plt.yticks([0.5,1,1.5,2,2.5]) 
plt.savefig('SIMONI/elastic_arbiter_4MBPS_P1203.png', format='png')

# %%
fig = plt.figure()


with plt.style.context('Solarize_Light2'):
    fig.set_facecolor('white')
    plt.rcParams['axes.facecolor'] = 'white'
    plt.plot(elastic_df_8['intSeg'], elastic_df_8['intSta'], label='Elastic')
    plt.plot(arbiter_df_8['intSeg'], arbiter_df_8['intSta'], label='Arbiter +',linestyle='--',color='orange')
    plt.title('Bandwidth: 0.5 - 4 Mbps', fontsize=12)
    plt.xlabel('Segments (2 sec)', fontsize=12, color='black')
    plt.ylabel('Stall (ms)', fontsize=12, color='black')
    plt.legend(frameon=False)
    plt.grid(axis='y', c='grey',alpha=0.2)
    plt.grid(axis='x', c='grey',alpha=0.2)
    plt.tick_params(axis='x', colors='black')
    plt.tick_params(axis='y', colors='black')
    plt.savefig('SIMONI/elastic_arbiter_4MBPS_stall.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(6,3.5)) 
plt.step(exp_df_8['intSeg'], exp_df_8['P1203'], label='Exponential' )
plt.step(conv_df_8['intSeg'], conv_df_8['P1203'], label='Arbiter +',linestyle='--', color='orange')
#lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 0.5 - 4 Mbps')
plt.grid(True)
plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('P.1203', fontsize=12, color='black')
plt.yticks([2,2.5,3,3.5,4]) 
plt.savefig('SIMONI/exp_conv_4MBPS_P1203.png', format='png')

# %%
fig = plt.figure()


with plt.style.context('Solarize_Light2'):
    fig.set_facecolor('white')
    plt.rcParams['axes.facecolor'] = 'white'
    plt.plot(exp_df_8['intSeg'], exp_df_8['intSta'], label='Exponential')
    plt.plot(conv_df_8['intSeg'], conv_df_8['intSta'], label='Conventional',linestyle='--',color='orange')
    plt.title('Bandwidth: 0.5 - 4 Mbps', fontsize=12)
    plt.xlabel('Segments (2 sec)', fontsize=12, color='black')
    plt.ylabel('Stall (ms)', fontsize=12, color='black')
    plt.legend(frameon=False)
    plt.grid(axis='y', c='grey',alpha=0.2)
    plt.grid(axis='x', c='grey',alpha=0.2)
    plt.tick_params(axis='x', colors='black')
    plt.tick_params(axis='y', colors='black')
    plt.savefig('SIMONI/exp_conv_4MBPS_stall.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(6,3.5)) 
plt.step(exp_df_10['intSeg'], exp_df_10['P1203'], label='Exponential' )
plt.step(conv_df_10['intSeg'], conv_df_10['P1203'], label='Arbiter +',linestyle='--', color='orange')
#lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 6 - 14 Mbps')
plt.grid(True)
plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('P.1203', fontsize=12, color='black')
plt.yticks([2,2.5,3,3.5,4]) 
plt.savefig('SIMONI/exp_conv_14MBPS_P1203.png', format='png')

# %%
fig = plt.figure()


with plt.style.context('Solarize_Light2'):
    fig.set_facecolor('white')
    plt.rcParams['axes.facecolor'] = 'white'
    plt.plot(exp_df_10['intSeg'], exp_df_10['intSta'], label='Exponential')
    plt.plot(conv_df_10['intSeg'], conv_df_10['intSta'], label='Conventional',linestyle='--',color='orange')
    plt.title('Bandwidth: 0.5 - 4 Mbps', fontsize=12)
    plt.xlabel('Segments (2 sec)', fontsize=12, color='black')
    plt.ylabel('Stall (ms)', fontsize=12, color='black')
    plt.legend(frameon=False)
    plt.grid(axis='y', c='grey',alpha=0.2)
    plt.grid(axis='x', c='grey',alpha=0.2)
    plt.tick_params(axis='x', colors='black')
    plt.tick_params(axis='y', colors='black')
    plt.savefig('SIMONI/exp_conv_14MBPS_stall.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(8,3.5)) 
plt.step(exp_df_10['intSeg'], exp_df_10['Clae'], label='Exponential' )
plt.step(conv_df_10['intSeg'], conv_df_10['Clae'], label='Conventional')
plt.step(bba_df_10['intSeg'], bba_df_10['Clae'], label='BBA-2 +')
plt.step(logistic_df_10['intSeg'], logistic_df_10['Clae'], label='Logistic')
plt.step(arbiter_df_10['intSeg'], arbiter_df_10['Clae'], label='Arbiter +')
plt.step(elastic_df_10['intSeg'], elastic_df_10['Clae'], label='Elastic')


lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 4 - 14 Mbps')
plt.grid(True)
#plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('Clae', fontsize=12, color='black')
plt.subplots_adjust(right=0.71)
plt.savefig('STALL/Clae_4_14mbps.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(8,3.5)) 
plt.step(exp_df_8['intSeg'], exp_df_8['Clae'], label='Exponential' )
plt.step(conv_df_8['intSeg'], conv_df_8['Clae'], label='Conventional')
plt.step(bba_df_8['intSeg'], bba_df_8['Clae'], label='BBA-2 +')
plt.step(logistic_df_8['intSeg'], logistic_df_8['Clae'], label='Logistic')
plt.step(arbiter_df_8['intSeg'], arbiter_df_8['Clae'], label='Arbiter +')
plt.step(elastic_df_8['intSeg'], elastic_df_8['Clae'], label='Elastic')


lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 0.5 - 4 Mbps')
plt.grid(True)
#plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('Clae', fontsize=12, color='black')
plt.subplots_adjust(right=0.71)
plt.savefig('STALL/Clae_5_4mbps.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(8,3.5)) 
plt.step(exp_df_10['intSeg'], exp_df_10['Duanmu'], label='Exponential' )
plt.step(conv_df_10['intSeg'], conv_df_10['Duanmu'], label='Conventional')
plt.step(bba_df_10['intSeg'], bba_df_10['Duanmu'], label='BBA-2 +')
plt.step(logistic_df_10['intSeg'], logistic_df_10['Duanmu'], label='Logistic')
plt.step(arbiter_df_10['intSeg'], arbiter_df_10['Duanmu'], label='Arbiter +')
plt.step(elastic_df_10['intSeg'], elastic_df_10['Duanmu'], label='Elastic')


lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 4 - 14 Mbps')
plt.grid(True)
#plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('Duanmu', fontsize=12, color='black')
plt.subplots_adjust(right=0.71)
plt.savefig('STALL/Duanmu_4_14mbps.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(8,3.5)) 
plt.step(exp_df_8['intSeg'], exp_df_8['Duanmu'], label='Exponential' )
plt.step(conv_df_8['intSeg'], conv_df_8['Duanmu'], label='Conventional')
plt.step(bba_df_8['intSeg'], bba_df_8['Duanmu'], label='BBA-2 +')
plt.step(logistic_df_8['intSeg'], logistic_df_8['Duanmu'], label='Logistic')
plt.step(arbiter_df_8['intSeg'], arbiter_df_8['Duanmu'], label='Arbiter +')
plt.step(elastic_df_8['intSeg'], elastic_df_8['Duanmu'], label='Elastic')


lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 0.5 - 4 Mbps')
plt.grid(True)
#plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('Duanmu', fontsize=12, color='black')
plt.subplots_adjust(right=0.71)
plt.savefig('STALL/Duanmu_5_4mbps.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(8,3.5)) 
plt.step(exp_df_10['intSeg'], exp_df_10['Yin'], label='Exponential' )
plt.step(conv_df_10['intSeg'], conv_df_10['Yin'], label='Conventional')
plt.step(bba_df_10['intSeg'], bba_df_10['Yin'], label='BBA-2 +')
plt.step(logistic_df_10['intSeg'], logistic_df_10['Yin'], label='Logistic')
plt.step(arbiter_df_10['intSeg'], arbiter_df_10['Yin'], label='Arbiter +')
plt.step(elastic_df_10['intSeg'], elastic_df_10['Yin'], label='Elastic')


lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 4 - 14 Mbps')
plt.grid(True)
#plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('Yin', fontsize=12, color='black')
plt.subplots_adjust(right=0.71)
plt.savefig('STALL/Yin_4_14mbps.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(8,3.5)) 
plt.step(exp_df_8['intSeg'], exp_df_8['Yin'], label='Exponential' )
plt.step(conv_df_8['intSeg'], conv_df_8['Yin'], label='Conventional')
plt.step(bba_df_8['intSeg'], bba_df_8['Yin'], label='BBA-2 +')
plt.step(logistic_df_8['intSeg'], logistic_df_8['Yin'], label='Logistic')
plt.step(arbiter_df_8['intSeg'], arbiter_df_8['Yin'], label='Arbiter +')
plt.step(elastic_df_8['intSeg'], elastic_df_8['Yin'], label='Elastic')


lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 0.5 - 4 Mbps')
plt.grid(True)
#plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('Yin', fontsize=12, color='black')
plt.subplots_adjust(right=0.71)
plt.savefig('STALL/Yin_5_4mbps.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(8,3.5)) 
plt.step(exp_df_10['intSeg'], exp_df_10['Yu'], label='Exponential' )
plt.step(conv_df_10['intSeg'], conv_df_10['Yu'], label='Conventional')
plt.step(bba_df_10['intSeg'], bba_df_10['Yu'], label='BBA-2 +')
plt.step(logistic_df_10['intSeg'], logistic_df_10['Yu'], label='Logistic')
plt.step(arbiter_df_10['intSeg'], arbiter_df_10['Yu'], label='Arbiter +')
plt.step(elastic_df_10['intSeg'], elastic_df_10['Yu'], label='Elastic')


lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 4 - 14 Mbps')
plt.grid(True)
#plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('Yu', fontsize=12, color='black')
plt.subplots_adjust(right=0.71)
plt.savefig('STALL/Yu_4_14mbps.png', format='png')

# %%
matplotlib.rc('axes',edgecolor='grey')
ax = plt.figure()
plt.rcParams['axes.facecolor'] = 'white'
plt.figure(figsize=(8,3.5)) 
plt.step(exp_df_8['intSeg'], exp_df_8['Yu'], label='Exponential' )
plt.step(conv_df_8['intSeg'], conv_df_8['Yu'], label='Conventional')
plt.step(bba_df_8['intSeg'], bba_df_8['Yu'], label='BBA-2 +')
plt.step(logistic_df_8['intSeg'], logistic_df_8['Yu'], label='Logistic')
plt.step(arbiter_df_8['intSeg'], arbiter_df_8['Yu'], label='Arbiter +')
plt.step(elastic_df_8['intSeg'], elastic_df_8['Yu'], label='Elastic')


lgd = plt.legend(bbox_to_anchor=(1.01, 1.02), loc='upper left',frameon=False)
plt.title('Bandwidth: 0.5 - 4 Mbps')
plt.grid(True)
#plt.legend(frameon=False)
plt.xlabel('Segments', fontsize=12, color='black')
plt.ylabel('Yu', fontsize=12, color='black')
plt.subplots_adjust(right=0.71)
plt.savefig('STALL/Yu_5_4mbps.png', format='png')
