# %%
import numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("5G_Netflix_ALL - Sheet13.csv")

# %%
#df.Width.replace({320:1, 384:2,640:3,736:4,1280:5,1920:6}, inplace=True)

# %%
df.columns
# Out:
# Index(['intExpID', 'Column', 'total_users', 'intSeg', 'intArr', 'intDel',
#        'intSta', 'intRep', 'intDelRate', 'intActRate', 'intByteSize',
#        'floatBuf', 'algorithm_used', 'Seg_Dur', 'Codec', 'Width', 'Height',
#        'Resolutions', 'FPS', 'Play_Pos', 'RTT', 'Protocol', 'P1203', 'Clae',
#        'Duanmu', 'Yin', 'Yu', 'intUser', 'port', 'rtt_qos', 'tp_qos', 'p_qos'],
#       dtype='object')

# %%
#df.columns

# %%
df['Column'].unique()
# Out:
# array([11, 10,  9,  7,  8,  2,  5,  1,  4])

# %%
df_10 =df[(df['intUser']==2) & (df['total_users']==2) & (df['Column']==9)]

# %%
df_8 =df[(df['intUser']==2)& (df['total_users']==2) & (df['Column']==11)]

# %%
df_10.shape[0]
# Out:
# 420

# %%
col_1_df_10 = df_10[(df_10['algorithm_used']=='elastic')]
col_2_df_10 = df_10[(df_10['algorithm_used']=='arbiter')]
col_3_df_10 = df_10[(df_10['algorithm_used']=='average')]
col_4_df_10 = df_10[(df_10['algorithm_used']=='exponential')]
col_5_df_10 = df_10[(df_10['algorithm_used']=='conventional')]
col_6_df_10 = df_10[(df_10['algorithm_used']=='bba')]
col_7_df_10 = df_10[(df_10['algorithm_used']=='logistic')]

# %%
col_1_df_8 = df_8[(df_8['algorithm_used']=='elastic')]
col_2_df_8 = df_8[(df_8['algorithm_used']=='arbiter')]
col_3_df_8 = df_8[(df_8['algorithm_used']=='average')]
col_4_df_8 = df_8[(df_8['algorithm_used']=='exponential')]
col_5_df_8 = df_8[(df_8['algorithm_used']=='conventional')]
col_6_df_8 = df_8[(df_8['algorithm_used']=='bba')]
col_7_df_8 = df_8[(df_8['algorithm_used']=='logistic')]

# %%
fig, axs = plt.subplots(4,2,constrained_layout=False,figsize=(10,5.5))
(ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8) = axs
fig.suptitle('Rate based: Exponential & Conventional [Low - High] Mbps')
#plt.rcParams['ytick.right'] = plt.rcParams['ytick.labelright'] = True
#plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

l1,=ax1.plot(col_4_df_8['intSeg'], col_4_df_8['intActRate'],linestyle=':')
l2,=ax1.plot(col_4_df_10['intSeg'], col_4_df_10['intActRate'],linestyle='--')
#l3,= ax1.plot(col_4_df_8['intSeg'], col_4_df_8['intActRate'],linestyle='-.')


#P.1203 of above
ax3.plot(col_4_df_8['intSeg'], col_4_df_8['P1203'],linestyle=':')
ax3.plot(col_4_df_10['intSeg'], col_4_df_10['P1203'],linestyle='--')
#ax3.plot(col_4_df_8['intSeg'], col_4_df_8['P1203'],linestyle='-.')

ax5.plot(col_4_df_8['intSeg'], col_4_df_8['rtt_qos'],linestyle=':')
ax5.plot(col_4_df_10['intSeg'], col_4_df_10['rtt_qos'],linestyle='--')
#ax5.plot(col_4_df_8['intSeg'], col_4_df_8['rtt_qos'],linestyle='-.')

ax7.plot(col_4_df_8['intSeg'], col_4_df_8['intSta'],linestyle=':')
ax7.plot(col_4_df_10['intSeg'], col_4_df_10['intSta'],linestyle='--')
#ax7.plot(col_4_df_8['intSeg'], col_4_df_8['intSta'],linestyle='-.')



ax2.plot(col_5_df_8['intSeg'], col_5_df_8['intActRate'],linestyle=':')
ax2.plot(col_5_df_10['intSeg'], col_5_df_10['intActRate'],linestyle='--')
#ax2.plot(col_5_df_8['intSeg'], col_5_df_8['intActRate'],linestyle='-.')

#P.1203 of above
ax4.plot(col_5_df_8['intSeg'], col_5_df_8['P1203'],linestyle=':')
ax4.plot(col_5_df_10['intSeg'], col_5_df_10['P1203'],linestyle='--')
#ax4.plot(col_5_df_8['intSeg'], col_5_df_8['P1203'],linestyle='-.')

ax6.plot(col_5_df_8['intSeg'], col_5_df_8['rtt_qos'],linestyle=':')
ax6.plot(col_5_df_10['intSeg'], col_5_df_10['rtt_qos'],linestyle='--')
#ax6.plot(col_5_df_8['intSeg'], col_5_df_8['rtt_qos'],linestyle='-.')

ax8.plot(col_5_df_8['intSeg'], col_5_df_8['intSta'],linestyle=':')
ax8.plot(col_5_df_10['intSeg'], col_5_df_10['intSta'],linestyle='--')
#ax8.plot(col_5_df_8['intSeg'], col_5_df_8['intSta'],linestyle='-.')


#plt.legend([l1, l2,l3],["0.1-1 Mbps", "7-8 Mbps","13-14 Mbps"])
#for ax in axs.flat:
    #ax.label_outer()
    
for ax in axs.flat:
    ax.label_outer()

#
plt.legend([l1, l2],["0.5 - 7 Mbps", "8 - 72 Mbps"], loc='upper right', bbox_to_anchor=(0.40, 5.20), ncol=3, fancybox=True, shadow=False)



ax7.set(ylabel='Stall (ms)')
ax5.set(ylabel='RTT')
ax3.set(ylabel='P.1203')
ax1.set(ylabel='Bitrate')
plt.subplots_adjust(top=0.85)
plt.savefig('STATIC/5G_RATE_STATIC.png', format='png')

# %%
fig, axs = plt.subplots(4,2,constrained_layout=False,figsize=(10,5.5))
(ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8) = axs
fig.suptitle('Hybrid: Elastic & Arbiter [Low - High] Mbps')
#plt.rcParams['ytick.right'] = plt.rcParams['ytick.labelright'] = True
#plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

l1,=ax1.plot(col_1_df_8['intSeg'], col_1_df_8['intActRate'],linestyle=':')
l2,=ax1.plot(col_1_df_10['intSeg'], col_1_df_10['intActRate'],linestyle='--')
#l3,= ax1.plot(col_1_df_8['intSeg'], col_1_df_8['intActRate'],linestyle='-.')


#P.1203 of above
ax3.plot(col_1_df_8['intSeg'], col_1_df_8['P1203'],linestyle=':')
ax3.plot(col_1_df_10['intSeg'], col_1_df_10['P1203'],linestyle='--')
#ax3.plot(col_1_df_8['intSeg'], col_1_df_8['P1203'],linestyle='-.')

ax5.plot(col_1_df_8['intSeg'], col_1_df_8['rtt_qos'],linestyle=':')
ax5.plot(col_1_df_10['intSeg'], col_1_df_10['rtt_qos'],linestyle='--')
#ax5.plot(col_1_df_8['intSeg'], col_1_df_8['rtt_qos'],linestyle='-.')

ax7.plot(col_1_df_8['intSeg'], col_1_df_8['intSta'],linestyle=':')
ax7.plot(col_1_df_10['intSeg'], col_1_df_10['intSta'],linestyle='--')
#ax7.plot(col_1_df_8['intSeg'], col_1_df_8['intSta'],linestyle='-.')



ax2.plot(col_2_df_8['intSeg'], col_2_df_8['intActRate'],linestyle=':')
ax2.plot(col_2_df_10['intSeg'], col_2_df_10['intActRate'],linestyle='--')
#ax2.plot(col_2_df_8['intSeg'], col_2_df_8['intActRate'],linestyle='-.')

#P.1203 of above
ax4.plot(col_2_df_8['intSeg'], col_2_df_8['P1203'],linestyle=':')
ax4.plot(col_2_df_10['intSeg'], col_2_df_10['P1203'],linestyle='--')
#ax4.plot(col_2_df_8['intSeg'], col_2_df_8['P1203'],linestyle='-.')

ax6.plot(col_2_df_8['intSeg'], col_2_df_8['rtt_qos'],linestyle=':')
ax6.plot(col_2_df_10['intSeg'], col_2_df_10['rtt_qos'],linestyle='--')
#ax6.plot(col_2_df_8['intSeg'], col_2_df_8['rtt_qos'],linestyle='-.')

ax8.plot(col_2_df_8['intSeg'], col_2_df_8['intSta'],linestyle=':')
ax8.plot(col_2_df_10['intSeg'], col_2_df_10['intSta'],linestyle='--')
#ax8.plot(col_2_df_8['intSeg'], col_2_df_8['intSta'],linestyle='-.')


#plt.legend([l1, l2,l3],["0.1-1 Mbps", "7-8 Mbps","13-14 Mbps"])
#for ax in axs.flat:
    #ax.label_outer()
    
for ax in axs.flat:
    ax.label_outer()

#
plt.legend([l1, l2],["0.5 - 7 Mbps", "8 - 72 Mbps"], loc='upper right', bbox_to_anchor=(0.40, 5.20), ncol=3, fancybox=True, shadow=False)



ax7.set(ylabel='Stall (ms)')
ax5.set(ylabel='RTT')
ax3.set(ylabel='P.1203')
ax1.set(ylabel='Bitrate')
plt.subplots_adjust(top=0.85)
plt.savefig('STATIC/5G_HYBRID_STATIC.png', format='png')

# %%
fig, axs = plt.subplots(4,2,constrained_layout=False,figsize=(10,5.5))
(ax1, ax2), (ax3, ax4), (ax5, ax6), (ax7, ax8) = axs
fig.suptitle('Buffered: BBA-2 + & Logistic [Low - High] Mbps')
#plt.rcParams['ytick.right'] = plt.rcParams['ytick.labelright'] = True
#plt.rcParams['ytick.left'] = plt.rcParams['ytick.labelleft'] = False

l1,=ax1.plot(col_6_df_8['intSeg'], col_6_df_8['intActRate'],linestyle=':')
l2,=ax1.plot(col_6_df_10['intSeg'], col_6_df_10['intActRate'],linestyle='--')
#l3,= ax1.plot(col_6_df_8['intSeg'], col_6_df_8['intActRate'],linestyle='-.')


#P.1203 of above
ax3.plot(col_6_df_8['intSeg'], col_6_df_8['P1203'],linestyle=':')
ax3.plot(col_6_df_10['intSeg'], col_6_df_10['P1203'],linestyle='--')
#ax3.plot(col_6_df_8['intSeg'], col_6_df_8['P1203'],linestyle='-.')

ax5.plot(col_6_df_8['intSeg'], col_6_df_8['rtt_qos'],linestyle=':')
ax5.plot(col_6_df_10['intSeg'], col_6_df_10['rtt_qos'],linestyle='--')
#ax5.plot(col_6_df_8['intSeg'], col_6_df_8['rtt_qos'],linestyle='-.')

ax7.plot(col_7_df_8['intSeg'], col_6_df_8['intSta'],linestyle=':')
ax7.plot(col_7_df_10['intSeg'], col_6_df_10['intSta'],linestyle='--')
#ax7.plot(col_7_df_8['intSeg'], col_6_df_8['intSta'],linestyle='-.')



ax2.plot(col_7_df_8['intSeg'], col_7_df_8['intActRate'],linestyle=':')
ax2.plot(col_7_df_10['intSeg'], col_7_df_10['intActRate'],linestyle='--')
#ax2.plot(col_7_df_8['intSeg'], col_7_df_8['intActRate'],linestyle='-.')

#P.1203 of above
ax4.plot(col_7_df_8['intSeg'], col_7_df_8['P1203'],linestyle=':')
ax4.plot(col_7_df_10['intSeg'], col_7_df_10['P1203'],linestyle='--')
#ax4.plot(col_7_df_8['intSeg'], col_7_df_8['P1203'],linestyle='-.')

ax6.plot(col_7_df_8['intSeg'], col_7_df_8['rtt_qos'],linestyle=':')
ax6.plot(col_7_df_10['intSeg'], col_7_df_10['rtt_qos'],linestyle='--')
#ax6.plot(col_7_df_8['intSeg'], col_7_df_8['rtt_qos'],linestyle='-.')

ax8.plot(col_7_df_8['intSeg'], col_7_df_8['intSta'],linestyle=':')
ax8.plot(col_7_df_10['intSeg'], col_7_df_10['intSta'],linestyle='--')
#ax8.plot(col_7_df_8['intSeg'], col_7_df_8['intSta'],linestyle='-.')


#plt.legend([l1, l2,l3],["0.1-1 Mbps", "7-8 Mbps","13-14 Mbps"])
#for ax in axs.flat:
    #ax.label_outer()
    
for ax in axs.flat:
    ax.label_outer()

#
plt.legend([l1, l2],["0.5 - 7 Mbps", "8 - 72 Mbps"], loc='upper right', bbox_to_anchor=(0.40, 5.20), ncol=3, fancybox=True, shadow=False)



ax7.set(ylabel='Stall (ms)')
ax5.set(ylabel='RTT')
ax3.set(ylabel='P.1203')
ax1.set(ylabel='Bitrate')
plt.subplots_adjust(top=0.85)
plt.savefig('STATIC/5G_BUFFERED_STATIC.png', format='png')
